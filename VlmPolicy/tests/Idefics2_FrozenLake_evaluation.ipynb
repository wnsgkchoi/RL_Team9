# %% [markdown]
# # Idefics2 finetuning of FrozenLake descriptions
#
# We load the model with LoRA and quantization

# %%
from datasets import load_dataset
from evaluate import load
from transformers import Idefics2ForConditionalGeneration, BitsAndBytesConfig, AutoProcessor
import torch
from tqdm import tqdm
import json
import colorama

# %%
vanilla_idefics2_path = "HuggingFaceM4/idefics2-8b"
finetuned_idfics2_path = "dawoz/idefics2-frozenlake"

# %%
def load_model(model_path):

    processor = AutoProcessor.from_pretrained(
        "HuggingFaceM4/idefics2-8b",
        do_image_splitting=False
    )
    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.float16
    )
    model = Idefics2ForConditionalGeneration.from_pretrained(
        model_path,
        torch_dtype=torch.float16,
        quantization_config=bnb_config
    )
        
    return model, processor

# %%
def compute_predictions(model, processor, *, dataset, batch_size=4):
    model.eval()
    
    true_answers = []
    predicted_answers = []
    start_indexes = []

    for i in tqdm(range(0, len(dataset), batch_size)):
        examples = dataset[i: i + batch_size]
        true_answers.extend(examples["answer"])
        images = [[im] for im in examples["image"]]
        
        texts = []
        for instruction in examples["instruction"]:
            messages = [
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": instruction},
                        {"type": "image"},
                    ]
                }
            ]
            text = processor.apply_chat_template(messages, add_generation_prompt=True)
            texts.append(text.strip())
            start_indexes.append(0)
            
        inputs = processor(text=texts, images=images, return_tensors="pt", padding=True)
        generated_ids = model.generate(**inputs, max_new_tokens=64)
        generated_texts = processor.batch_decode(generated_ids[:, inputs["input_ids"].size(1):], skip_special_tokens=True)
        predicted_answers.extend(generated_texts)
    
    return {
        "true_answers": true_answers,
        "predicted_answers": predicted_answers,
        "start_indexes": start_indexes
    }

# %% [markdown]
# ### Average Normalized Levenshtein Similarity (useful??)
#
# During the training, we tracked the loss on the evaluation split. It is interesting to measure the performance using the "true metric" used for DocVQA.
#
# The metric at hand is the *Average Normalized Levenshtein Similarity* (ANLS). The Average Normalized Levenshtein Similarity (ANLS) proposed by [Biten+ ICCV'19](https://arxiv.org/abs/1905.13648) smoothly captures the OCR mistakes applying a slight penalization in case of correct intended responses, but badly recognized. It also makes use of a threshold of value 0.5 that dictates whether the output of the metric will be the ANLS if its value is equal or bigger than 0.5 or 0 otherwise. The key point of this threshold is to determine if the answer has been correctly selected but not properly recognized, or on the contrary, the output is a wrong text selected from the options and given as an answer.
#
# We first define a few utilities to compute the ANLS.

# %%
def normalized_levenshtein(s1, s2):
    len_s1, len_s2 = len(s1), len(s2)
    distance = Levenshtein.distance(s1, s2)
    return distance / max(len_s1, len_s2)

def similarity_score(a_ij, o_q_i, tau=0.5):
    nl = normalized_levenshtein(a_ij, o_q_i)
    return 1 - nl if nl < tau else 0

def average_normalized_levenshtein_similarity(ground_truth, predicted_answers):
    assert len(ground_truth) == len(predicted_answers), "Length of ground_truth and predicted_answers must match."

    N = len(ground_truth)
    total_score = 0

    for i in range(N):
        a_i = ground_truth[i]
        o_q_i = predicted_answers[i]
        if o_q_i == "":
            print("Warning: Skipped an empty prediction.")
            max_score = 0
        else:
            max_score = max(similarity_score(a_ij, o_q_i) for a_ij in a_i)

        total_score += max_score

    return total_score / N

# %% [markdown]
# ### Squad metric (exact match + F1 score)
#
# Exact match: trivial
#
# F1 score:
# - precision: {num predicted tokens in ground truth} / {num predicted tokens}
# - recall: {num predicted tokens in ground trugh} / {num ground truth tokens}
# - F1 = 2 * (prec * rec) / (prec + rec)
#
# https://huggingface.co/learn/nlp-course/chapter7/7?fw=pt#post-processing

# %%
def eval_frozen_knowledge(model, processor, *, dataset_path='dawoz/frozenlake_prompts_dataset', eval_batch_size=4):
    dataset = load_dataset(dataset_path, split='test')

    output = compute_predictions(model, processor, dataset=dataset, batch_size=eval_batch_size)
    true_answers = output["true_answers"]
    predicted_answers = output["predicted_answers"]
    start_indexes = output["start_indexes"]
        
    squad = load('squad')

    predictions = [{"id": str(i), "prediction_text": e} for i, e in enumerate(predicted_answers)]
    references = [{"id": str(i), "answers": {'text': [e], "answer_start": [s]}}
                  for i, (e, s) in enumerate(zip(true_answers, start_indexes))
                  ]

    res = squad.compute(predictions=predictions, references=references)
    
    # save predictions and references
    res['predictions'] = predictions
    res['references'] = references
    
    # ANLS (?)

    return res

# %% [markdown]
# ## Start evaluation

# %%
model, processor = load_model(vanilla_idefics2_path)

output_vanilla = eval_frozen_knowledge(model, processor)

with open('eval_output/output_vanilla.json', 'w') as f:
    json.dump(output_vanilla, f, indent=4)
    
del model, processor
torch.cuda.empty_cache()
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]/home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages/transformers/generation/utils.py:1659: UserWarning: You are calling .generate() with the `input_ids` being on a device type different than your model's device. `input_ids` is on cpu, whereas the model is on cuda. You may experience unexpected behaviors or slower generation. Please make sure that you have put `input_ids` to the correct device by calling for example input_ids = input_ids.to('cuda') before running `.generate()`.
#   warnings.warn(
# 100%|██████████| 25/25 [02:04<00:00,  4.97s/it]

# %%
model, processor = load_model(finetuned_idfics2_path)

output_finetuned = eval_frozen_knowledge(model, processor)

with open('eval_output/output_finetuned.json', 'w') as f:
    json.dump(output_finetuned, f, indent=4)
    
del model, processor
torch.cuda.empty_cache()
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/25 [00:00<?, ?it/s]/home/davide/miniconda3/envs/idefics/lib/python3.10/site-packages/transformers/generation/utils.py:1659: UserWarning: You are calling .generate() with the `input_ids` being on a device type different than your model's device. `input_ids` is on cpu, whereas the model is on cuda. You may experience unexpected behaviors or slower generation. Please make sure that you have put `input_ids` to the correct device by calling for example input_ids = input_ids.to('cuda') before running `.generate()`.
#   warnings.warn(
# 100%|██████████| 25/25 [01:59<00:00,  4.77s/it]

# %% [markdown]
# Observe results

# %%
with open('eval_output/output_vanilla.json', 'r') as f:
    output_vanilla = json.load(f)
    
with open('eval_output/output_finetuned.json', 'r') as f:
    output_finetuned = json.load(f)

# %%
print('Idefics2 before training:')
print(f'Exact match: {output_vanilla["exact_match"]:5.2f}%')
print(f'         F1: {output_vanilla["f1"]:5.2f}%')

print('\nIdefics2 after training:')
print(f'Exact match: {output_finetuned["exact_match"]:5.2f}%')
print(f'         F1: {output_finetuned["f1"]:5.2f}%')
# Out:
# Idefics2 before training:
# Exact match:  0.00%
#          F1: 17.86%
#
# Idefics2 after training:
# Exact match: 18.00%
#          F1: 73.17%

# %% [markdown]
# Observe single predictions

# %%
preds_vanilla = [p['prediction_text'] for p in output_vanilla['predictions']]
preds_finetuned = [p['prediction_text'] for p in output_finetuned['predictions']]
trues = [r['answers']['text'][0] for r in output_vanilla['references']]

for i, (pv, pf, t) in enumerate(zip(preds_vanilla, preds_finetuned, trues)):
    pv = pv.replace('\n', '\\n')[:200]
    pf = pf.replace('\n', '\\n')[:200]
    t = t.replace('\n', '\\n')[:200]    
    
    print(colorama.Fore.YELLOW + f'      Gold:   {t}' + colorama.Style.RESET_ALL)
    print(f'   Vanilla:   {pv}')
    print(colorama.Fore.GREEN + f'Fine-tuned:   {pf}' + colorama.Style.RESET_ALL)
    print()
# Out:
#       Gold:   The picture shows an ice cell
#    Vanilla:   The tile in the image is a blue and white tile with a repeating pattern.
# Fine-tuned:   The picture shows a hole
#
#       Gold:   The picture shows a hole
#    Vanilla:   The tile in the image is a blue tile with a white outline.
# Fine-tuned:   The picture shows a hole
#
#       Gold:   The picture shows a cracked hole
#    Vanilla:   The tile in the image is a blue tile with a black shape in the middle.
# Fine-tuned:   The picture shows a hole
#
#       Gold:   The picture shows the player (facing north)
#    Vanilla:   The tile shows a small elf standing on a snowy surface.
# Fine-tuned:   The picture shows the player (facing south)
#
#       Gold:   The picture shows the player (facing south)
#    Vanilla:   The tile shows a small elf with a green hat and red and green outfit.
# Fine-tuned:   The picture shows the player (facing south)
#
#       Gold:   The picture shows the player (facing east)
#    Vanilla:   The tile shows a small elf standing in the snow.
# Fine-tuned:   The picture shows the player (facing south)
#
#       Gold:   The picture shows the player (facing west)
#    Vanilla:   The tile in the image is a small, colorful tile with a green, red, and yellow design.
# Fine-tuned:   The picture shows the player (facing south)
#
#       Gold:   The picture shows the goal
#    Vanilla:   The tile shows a gift with a blue background and a bow on top.
# Fine-tuned:   The picture shows a chest
#
#       Gold:   The picture shows the start cell
#    Vanilla:   The tile in the image is a small red square with a white outline.
# Fine-tuned:   The picture shows the player (facing south)
#
#       Gold:   The last action executed by the player was to move north
#    Vanilla:   The last action executed by the player is moving the character to the right.
# Fine-tuned:   Describe the state of the environment from the player's perspective
#
#       Gold:   The maps has 81 cells
#    Vanilla:   4
# Fine-tuned:   The maps has 49 cells
#
#       Gold:   The cell [0, 0] contains a hole\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains ice\nThe cell [3, 0] contains ice\nThe cell [4, 0] contains ice\nThe cell [5, 0] contains the goal\nThe cell [0,
#    Vanilla:   The cell [0, 0] contains a tile with a blue background and a small person. The cell [0, 1] contains a tile with a blue background and a small person. The cell [0, 2] contains a tile with a blue backgr
# Fine-tuned:   The cell [0, 0] contains ice\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains ice\nThe cell [3, 0] contains ice\nThe cell [4, 0] contains ice\nThe cell [5, 0] contains
#
#       Gold:   The last action executed by the player was to move east
#    Vanilla:   The last action executed by the player is moving the character to the right.
# Fine-tuned:   Write the list of actions that are safe for the player to execute
#
#       Gold:   Based on the picture of the state above, it seems that the player can move left without dying
#    Vanilla:   The player can move around the map, collect items, and interact with non-player characters.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can move backward without dying
#
#       Gold:   Based on the picture of the state above, it seems that the goal is 2 steps to my east
#    Vanilla:   The player is at (1, 1). The goal is at (10, 10). The distance between the player and the goal is 9 steps.
# Fine-tuned:   Based on the picture of the state above, it seems that the goal is 10 steps to my south-east
#
#       Gold:   Based on the picture of the state above, it seems that the player can move right without dying
#    Vanilla:   The player can move to the right. They can also move to the left.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can move backward without dying
#
#       Gold:   The maps has 11 holes
#    Vanilla:   16
# Fine-tuned:   The maps has 10 holes
#
#       Gold:   Based on the picture of the state above, it seems that the player can move forward without dying
#    Vanilla:   The player can move around the map, collect items, and interact with other characters.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can move backward without dying
#
#       Gold:   The maps has 81 cells
#    Vanilla:   60
# Fine-tuned:   The maps has 49 cells
#
#       Gold:   The map shows: the goal 6 steps to the player's south-east
#    Vanilla:   The player is in a snowy environment, surrounded by ice and snow. There are small ponds of water scattered around, and the player is trying to find their way through the icy terrain.
# Fine-tuned:   The map shows: a wall 1 steps to the player's east, a trap 1 steps to the player's south, the goal 5 steps to the player's south-east
#
#       Gold:   The maps has 1 holes
#    Vanilla:   There are 4 holes in the environment.
# Fine-tuned:   The maps has 1 holes
#
#       Gold:   The cell [0, 0] contains the player\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains ice\nThe cell [3, 0] contains ice\nThe cell [4, 0] contains ice\nThe cell [5, 0] contains ice\nThe cell [6,
#    Vanilla:   The cell [0, 0] contains a tile with a house. The cell [1, 0] contains a tile with a tree. The cell [2, 0] contains a tile with a tree. The cell [3, 0] contains a tile with a tree. The cell [4
# Fine-tuned:   The cell [0, 0] contains ice\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains ice\nThe cell [3, 0] contains ice\nThe cell [4, 0] contains ice\nThe cell [5, 0] contains
#
#       Gold:   The maps has 25 holes
#    Vanilla:   7
# Fine-tuned:   The maps has 21 holes
#
#       Gold:   Based on the picture of the state above, it seems that the player is alive
#    Vanilla:   No, the player is not dead.
# Fine-tuned:   Based on the picture of the state above, it seems that the player is alive
#
#       Gold:   Based on the picture of the state above, it seems that the player is alive
#    Vanilla:   No, the player is not dead.
# Fine-tuned:   Based on the picture of the state above, it seems that the player is alive
#
#       Gold:   Based on the picture of the state above, it seems that the player is alive
#    Vanilla:   No, the player is not dead.
# Fine-tuned:   Based on the picture of the state above, it seems that the player is alive
#
#       Gold:   Based on the picture of the state above, it seems that the player should move right to reach the goal safely
#    Vanilla:   The player should move towards the gift box and collect it. Once the player has collected the gift box, they should move towards the goal, which is usually located at the end of the level.
# Fine-tuned:   Based on the picture of the state above, it seems that the player should move backward to reach the goal safely
#
#       Gold:   Based on the picture of the state above, it seems that the player can move forward without dying
#    Vanilla:   The player can safely execute the following actions:\n\n1. Move the character to the left or right.\n2. Jump over the water.\n3. Open the gift.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can move backward without dying
#
#       Gold:   Based on the picture of the state above, it seems that the player can move forward without dying
#    Vanilla:   The player can move around the map, collecting coins and avoiding enemies.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can move backward without dying
#
#       Gold:   The cell [0, 0] contains ice\nThe cell [1, 0] contains a hole\nThe cell [2, 0] contains ice\nThe cell [3, 0] contains the goal\nThe cell [0, 1] contains ice\nThe cell [1, 1] contains ice\nThe cell [2,
#    Vanilla:   The cell [0, 0] contains a tile with a Christmas elf. The cell [1, 0] contains a tile with a gift. The cell [2, 0] contains a tile with a puddle of water. The cell [3, 0] contains a tile with a gift
# Fine-tuned:   The cell [0, 0] contains ice\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains ice\nThe cell [3, 0] contains the goal\nThe cell [0, 1] contains ice\nThe cell [1, 1]
#
#       Gold:   Based on the picture of the state above, it seems that the player is alive
#    Vanilla:   No, the player is not dead.
# Fine-tuned:   Based on the picture of the state above, it seems that the player is alive
#
#       Gold:   The player can see 2 walls and no holes 1 step away from him
#    Vanilla:   The player's field of view includes several entities, such as a small elf, a gift, a block, and a blue object.
# Fine-tuned:   The player can see 2 walls and no holes 1 step away from him
#
#       Gold:   Based on the picture of the state above, it seems that the player can move forward without dying
#    Vanilla:   The player can move around the map, collect items, and interact with non-player characters.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can move backward without dying
#
#       Gold:   Based on the picture of the state above, it seems that the player can move forward without dying
#    Vanilla:   The player can move the character to the left or right. The player can also jump.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can move backward without dying
#
#       Gold:   The cell [0, 0] contains a hole\nThe cell [1, 0] contains the goal\nThe cell [0, 1] contains the start cell\nThe cell [1, 1] contains the player\n
#    Vanilla:   The cell [0, 0] contains a blue ice block. The cell [0, 1] contains a small red box. The cell [0, 2] contains a small green Christmas tree. The cell [0, 3] contains a small brown box.
# Fine-tuned:   The cell [0, 0] contains ice\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains the goal\nThe cell [0, 1] contains ice\nThe cell [1, 1] contains ice\nThe cell [2, 1]
#
#       Gold:   The cell [0, 0] contains a hole\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains the goal\nThe cell [0, 1] contains ice\nThe cell [1, 1] contains the player\nThe cell [2, 1] contains ice\nThe c
#    Vanilla:   The cell [0, 0] contains a tile with a small elf. The cell [1, 0] contains a tile with a blue ice block. The cell [2, 0] contains a tile with a small gift box. The cell [3, 0] contains a tile with a s
# Fine-tuned:   The cell [0, 0] contains ice\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains the goal\nThe cell [0, 1] contains ice\nThe cell [1, 1] contains ice\nThe cell [2, 1]
#
#       Gold:   The cell [0, 0] contains ice\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains ice\nThe cell [3, 0] contains ice\nThe cell [4, 0] contains ice\nThe cell [5, 0] contains ice\nThe cell [6, 0] cont
#    Vanilla:   The cell [0, 0] contains a tile with a house. The cell [1, 0] contains a tile with a house. The cell [2, 0] contains a tile with a house. The cell [3, 0] contains a tile with a house. The cell [4
# Fine-tuned:   The cell [0, 0] contains ice\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains ice\nThe cell [3, 0] contains ice\nThe cell [4, 0] contains ice\nThe cell [5, 0] contains
#
#       Gold:   Based on the picture of the state above, it seems that the player can move right without dying
#    Vanilla:   The player can move around the map. They can also collect items.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can move backward without dying
#
#       Gold:   Based on the picture of the state above, it seems that the player can move right without dying
#    Vanilla:   The player can move their character to any of the blue tiles. They can also collect the items that are in the chests.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can move backward without dying
#
#       Gold:   Based on the picture of the state above, it seems that the player should move backward to reach the goal safely
#    Vanilla:   The player should move towards the goal, avoiding any obstacles or enemies. They should use their abilities and items to overcome any challenges. They should also be aware of their surroundings and pl
# Fine-tuned:   Based on the picture of the state above, it seems that the player should move backward to reach the goal safely
#
#       Gold:   The maps has 22 holes
#    Vanilla:   50
# Fine-tuned:   The maps has 21 holes
#
#       Gold:   Based on the picture of the state above, it seems that the player can move left without dying
#    Vanilla:   The player can move the character to the left or right. The player can jump.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can move backward without dying
#
#       Gold:   Based on the picture of the state above, it seems that the player should move right to reach the goal safely
#    Vanilla:   The player should move towards the goal, avoiding any obstacles or enemies. They should use their abilities to overcome any challenges and collect any power-ups or items along the way. They should als
# Fine-tuned:   Based on the picture of the state above, it seems that the player should move backward to reach the goal safely
#
#       Gold:   Based on the picture of the state above, it seems that the player should move right to reach the goal safely
#    Vanilla:   The player should move their character to the right, avoiding the blue circles. They should also avoid the black circle, as it is a hazard. They should move towards the goal, which is located at the t
# Fine-tuned:   Based on the picture of the state above, it seems that the player should move backward to reach the goal safely
#
#       Gold:   The map shows: a wall 1 steps to the player's east, a trap 1 steps to the player's north, a trap 1 steps to the player's south, the goal 5 steps to the player's south
#    Vanilla:   The player is in a large, open area with a blue and white tiled floor. There are several small, blue circles scattered around the floor. In the distance, the player can see a small, red character.
# Fine-tuned:   The map shows: a wall 1 steps to the player's east, a trap 1 steps to the player's south, the goal 10 steps to the player's south-east
#
#       Gold:   The last action executed by the player was to move west
#    Vanilla:   The last action executed by the player is moving the character to the right.
# Fine-tuned:   Describe the state of the environment from the player's perspective
#
#       Gold:   The cell [0, 0] contains a hole\nThe cell [1, 0] contains the goal\nThe cell [0, 1] contains the player\nThe cell [1, 1] contains ice\n
#    Vanilla:   The cell [0, 0] contains a tile with a small elf. The cell [0, 1] contains a tile with a blue ice block. The cell [0, 2] contains a tile with a gift box.
# Fine-tuned:   The cell [0, 0] contains ice\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains the goal\nThe cell [0, 1] contains ice\nThe cell [1, 1] contains ice\nThe cell [2, 1]
#
#       Gold:   The maps has 64 cells
#    Vanilla:   10
# Fine-tuned:   The maps has 49 cells
#
#       Gold:   Based on the picture of the state above, it seems that the player should move backward to reach the goal safely
#    Vanilla:   The player should move towards the goal, avoiding any obstacles or enemies. They should use their skills and abilities to overcome any challenges along the way. They should also collect any items or p
# Fine-tuned:   Based on the picture of the state above, it seems that the player should move backward to reach the goal safely
#
#       Gold:   Based on the picture of the state above, it seems that the player can move left without dying
#    Vanilla:   The player can move their character to any of the blue tiles. They can also move their character to the red tile.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can move backward without dying
#
#       Gold:   The player can see 1 walls and 2 holes 1 step away from him
#    Vanilla:   The player's field of view includes a number of blue circles, a red object, and a blue object.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can see 1 walls and 1 holes 1 step away from him
#
#       Gold:   The cell [0, 0] contains ice\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains a hole\nThe cell [3, 0] contains ice\nThe cell [4, 0] contains ice\nThe cell [5, 0] contains ice\nThe cell [6, 0] c
#    Vanilla:   The cell [0, 0] contains a tile with a small red box on it. The cell [1, 0] contains a tile with a small blue box on it. The cell [2, 0] contains a tile with a small blue box on it. The cell [3, 0
# Fine-tuned:   The cell [0, 0] contains ice\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains ice\nThe cell [3, 0] contains ice\nThe cell [4, 0] contains ice\nThe cell [5, 0] contains
#
#       Gold:   The maps has 100 cells
#    Vanilla:   90
# Fine-tuned:   The maps has 121 cells
#
#       Gold:   The map shows: a trap 1 steps to the player's north, a trap right under me, a trap 1 steps to the player's south, the goal 4 steps to the player's south-east
#    Vanilla:   The player is standing on a large sheet of ice. They can see small holes in the ice, and there is a small red object nearby.
# Fine-tuned:   The map shows: a wall 1 steps to the player's east, a trap right under me, the goal 8 steps to the player's south
#
#       Gold:   The cell [0, 0] contains ice\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains a hole\nThe cell [3, 0] contains ice\nThe cell [4, 0] contains ice\nThe cell [5, 0] contains a hole\nThe cell [6, 0
#    Vanilla:   The cell [0, 0] contains a tile with a small person. The cell [1, 0] contains a tile with a chest. The cell [2, 0] contains a tile with a chest. The cell [3, 0] contains a tile with a chest. The cell
# Fine-tuned:   The cell [0, 0] contains ice\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains ice\nThe cell [3, 0] contains ice\nThe cell [4, 0] contains ice\nThe cell [5, 0] contains
#
#       Gold:   The maps has 64 cells
#    Vanilla:   1
# Fine-tuned:   The maps has 49 cells
#
#       Gold:   The cell [0, 0] contains ice\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains the goal\nThe cell [0, 1] contains ice\nThe cell [1, 1] contains a hole\nThe cell [2, 1] contains ice\nThe cell [0,
#    Vanilla:   The cell [0, 0] contains a tile with a small red mushroom. The cell [0, 1] contains a tile with a blue ice block. The cell [0, 2] contains a tile with a gift box. The cell [0, 3] contains a tile with
# Fine-tuned:   The cell [0, 0] contains ice\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains ice\nThe cell [3, 0] contains the goal\nThe cell [0, 1] contains ice\nThe cell [1, 1]
#
#       Gold:   Based on the picture of the state above, it seems that the goal is 15 steps to my south-east
#    Vanilla:   The player is at (1, 1). The goal is at (10, 10). The distance between the player and the goal is 9 steps.
# Fine-tuned:   Write the list of actions that are safe for the player to execute
#
#       Gold:   The maps has 12 holes
#    Vanilla:   1
# Fine-tuned:   The maps has 11 holes
#
#       Gold:   Based on the picture of the state above, it seems that the player is alive
#    Vanilla:   No, the player is not dead.
# Fine-tuned:   Based on the picture of the state above, it seems that the player is alive
#
#       Gold:   Based on the picture of the state above, it seems that the player should move right to reach the goal safely
#    Vanilla:   The player should move towards the goal, which is the blue ice block. They should avoid the red block, as it is a hazard. They should also avoid the small ice block, as it is not part of the goal.
# Fine-tuned:   Based on the picture of the state above, it seems that the player should move backward to reach the goal safely
#
#       Gold:   Based on the picture of the state above, it seems that the player should move right to reach the goal safely
#    Vanilla:   The player should move towards the blue circles, avoiding the red character. They should collect the items and reach the goal safely.
# Fine-tuned:   Based on the picture of the state above, it seems that the player should move backward to reach the goal safely
#
#       Gold:   The last action executed by the player was to move north
#    Vanilla:   The last action executed by the player is moving the character to the right.
# Fine-tuned:   Describe the state of the environment from the player's perspective
#
#       Gold:   The player can see no walls and 1 holes 1 step away from him
#    Vanilla:   The player's field of view includes a small red elf, a gift, and a large body of water.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can see 1 walls and no holes 1 step away from him
#
#       Gold:   The cell [0, 0] contains ice\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains ice\nThe cell [3, 0] contains ice\nThe cell [4, 0] contains ice\nThe cell [5, 0] contains ice\nThe cell [6, 0] cont
#    Vanilla:   The cell [0, 0] contains a tile with a blue background. The cell [1, 0] contains a tile with a blue background. The cell [2, 0] contains a tile with a blue background. The cell [3, 0] contains a tile
# Fine-tuned:   The cell [0, 0] contains ice\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains ice\nThe cell [3, 0] contains ice\nThe cell [4, 0] contains ice\nThe cell [5, 0] contains
#
#       Gold:   Based on the picture of the state above, it seems that the player can move backward without dying
#    Vanilla:   The player can move around the map, collect items, and interact with non-player characters.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can move backward without dying
#
#       Gold:   Based on the picture of the state above, it seems that the player can move left without dying
#    Vanilla:   The player can move around the map, collect items, and interact with non-player characters.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can move backward without dying
#
#       Gold:   The maps has 30 holes
#    Vanilla:   70
# Fine-tuned:   The maps has 24 holes
#
#       Gold:   The maps has 17 holes
#    Vanilla:   50
# Fine-tuned:   The maps has 18 holes 1 step away from the goal
#
#       Gold:   Based on the picture of the state above, it seems that the goal is 5 steps to my south-east
#    Vanilla:   The player is currently at (0, 0). The goal is at (10, 10). The distance between the player and the goal is 10 steps.
# Fine-tuned:   Based on the picture of the state above, it seems that the goal is 4 steps to my south-east
#
#       Gold:   The cell [0, 0] contains a hole\nThe cell [1, 0] contains a hole\nThe cell [2, 0] contains ice\nThe cell [3, 0] contains ice\nThe cell [4, 0] contains a hole\nThe cell [5, 0] contains ice\nThe cell [6
#    Vanilla:   The cell [0, 0] contains a grass tile. The cell [0, 1] contains a grass tile. The cell [0, 2] contains a grass tile. The cell [0, 3] contains a grass tile. The cell [0, 4] contains a grass tile
# Fine-tuned:   The cell [0, 0] contains ice\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains ice\nThe cell [3, 0] contains ice\nThe cell [4, 0] contains ice\nThe cell [5, 0] contains
#
#       Gold:   Based on the picture of the state above, it seems that the player can move right without dying
#    Vanilla:   The player can move the character to the left or right. The player can jump. The player can interact with the items.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can move forward without dying
#
#       Gold:   The last action executed by the player was to move west
#    Vanilla:   The last action executed by the player is to open the gift.
# Fine-tuned:   Describe the state of the environment from the player's perspective
#
#       Gold:   The map shows: a wall 1 steps to the player's north, a trap 1 steps to the player's south, the goal 10 steps to the player's south-east
#    Vanilla:   The player is in a large, open area with a blue and white tiled floor. There are several small, blue circles scattered around the floor. In the distance, the player can see a small, red figure standin
# Fine-tuned:   The map shows: a wall 1 steps to the player's east, a trap 1 steps to the player's south, the goal 10 steps to the player's south-east
#
#       Gold:   Based on the picture of the state above, it seems that the player can move backward without dying
#    Vanilla:   The player can move around the map, collect items, and interact with non-player characters.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can move backward without dying
#
#       Gold:   Based on the picture of the state above, it seems that the player can move right without dying
#    Vanilla:   The player can move around the map, collect items, and interact with non-player characters.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can move backward without dying
#
#       Gold:   Based on the picture of the state above, it seems that the goal is 1 steps to my east
#    Vanilla:   The player is currently at the top left of the screen. The goal is at the bottom right of the screen. To get to the goal, the player needs to move 10 steps down and 10 steps to the right.
# Fine-tuned:   Based on the picture of the state above, it seems that the goal is 3 steps to my south-east
#
#       Gold:   Based on the picture of the state above, it seems that the player should move right to reach the goal safely
#    Vanilla:   The player should move towards the goal, avoiding any obstacles or enemies. They should use their abilities and items to overcome any challenges. They should also be aware of their surroundings and pl
# Fine-tuned:   Based on the picture of the state above, it seems that the player should move backward to reach the goal safely
#
#       Gold:   The cell [0, 0] contains a hole\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains ice\nThe cell [3, 0] contains ice\nThe cell [4, 0] contains a hole\nThe cell [5, 0] contains ice\nThe cell [6, 0
#    Vanilla:   The cell [0, 0] contains a tile with a blue background and a red cross. The cell [1, 0] contains a tile with a blue background and a blue cross. The cell [2, 0] contains a tile with a blue background
# Fine-tuned:   The cell [0, 0] contains ice\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains ice\nThe cell [3, 0] contains ice\nThe cell [4, 0] contains ice\nThe cell [5, 0] contains
#
#       Gold:   The map shows: a trap 1 steps to the player's west, a trap 1 steps to the player's east, the goal 6 steps to the player's south-east
#    Vanilla:   The player is in a large, open area with a blue and white tiled floor. There are several small blue circles scattered around the floor. In the distance, the player can see a small, red house.
# Fine-tuned:   The map shows: a wall 1 steps to the player's east, a trap 1 steps to the player's south, the goal 10 steps to the player's south-east
#
#       Gold:   Based on the picture of the state above, it seems that the player can move right without dying
#    Vanilla:   The player can move the character to the right. The player can move the character to the left. The player can move the character up. The player can move the character down.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can move backward without dying
#
#       Gold:   Based on the picture of the state above, it seems that the player can move right without dying
#    Vanilla:   The player can move around the map. They can also open the gift.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can move backward without dying
#
#       Gold:   Based on the picture of the state above, it seems that the player should move right to reach the goal safely
#    Vanilla:   The player should move towards the goal, avoiding any obstacles or enemies. They should use their abilities to overcome any challenges and collect any items or power-ups along the way. They should als
# Fine-tuned:   Based on the picture of the state above, it seems that the player should move backward to reach the goal safely
#
#       Gold:   Based on the picture of the state above, it seems that the goal is 1 steps to my south
#    Vanilla:   The player is currently at the top left of the screen. The goal is at the bottom right of the screen. The distance between the player and the goal is 3 steps.
# Fine-tuned:   Based on the picture of the state above, it seems that the goal is 2 steps to my south-east
#
#       Gold:   Based on the picture of the state above, it seems that the goal is 5 steps to my south-east
#    Vanilla:   1. Go to the right.\n2. Go to the right.\n3. Go to the right.\n4. Go to the right.\n5. Go to the right.\n6. Go to the right.\n7. Go to the right.\n8. Go to the right.
# Fine-tuned:   Based on the picture of the state above, it seems that the goal is 8 steps to my south-east
#
#       Gold:   The maps has 16 cells
#    Vanilla:   4
# Fine-tuned:   The maps has 16 cells
#
#       Gold:   The map shows: a wall 1 steps to the player's west, a wall 1 steps to the player's south, the goal 1 steps to the player's east
#    Vanilla:   The player is in a lush, green forest filled with tall trees and a clear blue sky. The ground is covered in soft, green grass and there are small, colorful flowers scattered throughout. The air is fre
# Fine-tuned:   The player can see 2 walls and no holes 1 step away from him
#
#       Gold:   Based on the picture of the state above, it seems that the player should move backward to reach the goal safely
#    Vanilla:   1. Move the player towards the gift.\n2. Jump over the ice block.\n3. Collect the gift.\n4. Move towards the next goal.
# Fine-tuned:   Based on the picture of the state above, it seems that the player should move backward to reach the goal safely
#
#       Gold:   Based on the picture of the state above, it seems that the goal is 1 steps to my east
#    Vanilla:   The player is currently at the top left of the screen. The goal is at the bottom right of the screen. The distance between the player and the goal is 3 steps.
# Fine-tuned:   Based on the picture of the state above, it seems that the goal is 1 steps to my south
#
#       Gold:   The map shows: a wall 1 steps to the player's east, the goal 1 steps to the player's south
#    Vanilla:   The player is in a large, open area with a white and blue tiled floor. There are several small blue circles scattered around the floor.
# Fine-tuned:   The map shows: a wall 1 steps to the player's east, a trap 1 steps to the player's south, a trap 1 steps to the player's north, the goal 10 steps to the player's south
#
#       Gold:   The player can see no walls and 2 holes 1 step away from him
#    Vanilla:   The player's field of view includes a number of blue circles, a red cross, and a chest.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can see 1 walls and 1 holes 1 step away from him
#
#       Gold:   Based on the picture of the state above, it seems that the player can move left without dying
#    Vanilla:   The player can move to the right. The player can move to the left. The player can move up. The player can move down.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can move backward without dying
#
#       Gold:   The last action executed by the player was to move north
#    Vanilla:   The last action executed by the player is moving the character to the right.
# Fine-tuned:   Write the list of actions that are safe for the player to execute
#
#       Gold:   Based on the picture of the state above, it seems that the player should move backward to reach the goal safely
#    Vanilla:   1. The player should move towards the goal, which is represented by the blue water.\n2. The player should avoid the obstacles, such as the ice blocks and the gift box, which can slow down the player's
# Fine-tuned:   Based on the picture of the state above, it seems that the player should move backward to reach the goal safely
#
#       Gold:   The maps has 121 cells
#    Vanilla:   80
# Fine-tuned:   The maps has 121 cells
#
#       Gold:   The player can see 1 walls and no holes 1 step away from him
#    Vanilla:   The player's field of view includes a small elf, a chest, and several blue circles.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can see 1 walls and 5 holes 1 step away from him
#
#       Gold:   Based on the picture of the state above, it seems that the player can move left without dying
#    Vanilla:   The player can move the character to the left or right. The player can jump.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can move backward without dying
#
#       Gold:   The maps has 121 cells
#    Vanilla:   80
# Fine-tuned:   The maps has 121 cells
#
#       Gold:   The cell [0, 0] contains ice\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains a hole\nThe cell [3, 0] contains ice\nThe cell [4, 0] contains ice\nThe cell [5, 0] contains a hole\nThe cell [6, 0
#    Vanilla:   The cell [0, 0] contains a blue tile. The cell [1, 0] contains a blue tile. The cell [2, 0] contains a blue tile. The cell [3, 0] contains a blue tile. The cell [4, 0] contains a blue tile
# Fine-tuned:   The cell [0, 0] contains ice\nThe cell [1, 0] contains ice\nThe cell [2, 0] contains ice\nThe cell [3, 0] contains ice\nThe cell [4, 0] contains ice\nThe cell [5, 0] contains
#
#       Gold:   The player can see 2 walls and no holes 1 step away from him
#    Vanilla:   The player's field of view includes a small elf, a blue pool of water, and a gift box.
# Fine-tuned:   Based on the picture of the state above, it seems that the player can see 2 walls and no holes 1 step away from him
